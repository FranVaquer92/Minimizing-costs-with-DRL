# %% [markdown]
# # CASO PRÁCTICO 2 - MINIMIZACIÓN DE COSTES

# %% [markdown]
# ## TRAINING

# %%
#Import libraries and another python files
import os
import numpy as np
import random as rn

import environment
import brain
import dqn


os.environ['KMP_DUPLICATE_LIB_OK']='True'

#Set up reproducibility seeds
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
rn.seed(12345)

#SET UP OF THE PARAMETERS
epsilon = 0.3
number_actions = 5
direction_boundary = (number_actions - 1)/2
number_epochs = 100
max_memory = 3000
batch_size = 512
temperature_step = 1.5

#BUILD OF THE ENVIRONMENT BY THE CREATION OF ENVIRONMENT OBJECT
env = environment.Environment(optimal_temperature = (18.0, 24.0), initial_month = 0, initial_number_users = 20, initial_rate_data = 30)

#BUILD OF THE BRAIN BY THE CRATION OF BRAIN OBJECT
brain = brain.Brain(learning_rate = 0.00001, number_actions = number_actions)

#BUILD OF THE DQN MODEL BY THE CREATION OF DQN OBJECT
dqn = dqn.DQN(max_memory = max_memory, discount_factor = 0.9)

#ELECTION OF TRAIN MODE
train = True

#TRAINING THE AI
env.train = train
model = brain.model

if env.train:
    for epoch in range(1, number_epochs):
        total_reward = 0
        loss = 0.
        new_month = np.random.randint(0,12)
        env.reset(new_month = new_month)
        game_over = False
        current_state, _, _ = env.observe()
        timestep = 0
        #INITIALIZATION OF TIMESTEP BUCLE (Timestep = 1 minute) PER EPOCH
        while (not game_over) and (timestep <= 5*30*24*60):
            #RUN THE NEXT EXPLORATION ACTION
            if np.random.rand() <= epsilon:
                action = np.random.randint(0, number_actions)
            #RUN THE NEXT INFERENCE ACTION
            else:
                q_values = model.predict(current_state)
                action = np.argmax(q_values[0])
            if (action < direction_boundary):
                direction = -1
            else:
                direction = 1
            energy_ai = abs(action - direction_boundary) * temperature_step
            #UPLOAD ENVIRONMENT TO GET THE NEXT STATE
            next_state, reward, game_over = env.update_env(direction, energy_ai, month= int(timestep/(30*24*60)))
            total_reward += reward
            
            #STORE THE NEXT TRANSITION IN THE MEMORY
            dqn.remember([current_state, action, reward, next_state], game_over)
            
            #GET THE TWO BLOCKS DIVIDE BY ENTRIES AND OBJECTIVES
            inputs, targets = dqn.get_batch(model, batch_size)
            
            #CALCULATE THE LOSS FUNCTION USING ALL OF THE BLOCK OF ENTRIES AND OBJECTIVES
            loss += model.train_on_batch(inputs, targets)
            timestep += 1
            current_state = next_state
            
        #PRINT TRINING RESULTS AT THE FINISH OF EPOCHS
        print('\n')
        print('Epoch: {:03d}/{:03d}'.format(epoch, number_epochs))
        print(' - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: {:.0f} J'.format(env.total_energy_noai))
        print(' - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: {:.0f} J'.format(env.total_energy_ai))
        
        #SAVE THE MODEL TO USE IN FUTURE JOBS
        model.save('model_dql.h5')
# Out:
# Using TensorFlow backend.
# /Users/franvaquer92/Documents/GitHub/ia4business/Part 2 - Minimizing Costs/Minimizing cost FV/brain.py:29: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   self.model = Model(inputs = states, output = q_values)
# Epoch: 001/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 002/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 003/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 27 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 004/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 005/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 006/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 007/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 008/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 009/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 291 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 86 J
#
#
# Epoch: 010/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 011/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 012/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 37 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 12 J
#
#
# Epoch: 013/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 014/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 015/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 3 J
#
#
# Epoch: 016/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 017/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 018/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 019/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 020/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 17 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 021/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 022/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 023/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 024/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 025/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 026/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 027/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 3 J
#
#
# Epoch: 028/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 029/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 030/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 031/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 032/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 18 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 3 J
#
#
# Epoch: 033/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 034/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 035/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 036/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 037/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 038/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 039/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 17 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 3 J
#
#
# Epoch: 040/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 3 J
#
#
# Epoch: 041/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 3 J
#
#
# Epoch: 042/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 25 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 043/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 044/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 045/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 046/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 047/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 048/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 049/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 050/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 3 J
#
#
# Epoch: 051/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 052/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 053/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 054/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 055/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 056/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 3 J
#
#
# Epoch: 057/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 058/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 3 J
#
#
# Epoch: 059/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 133 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 10 J
#
#
# Epoch: 060/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 061/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 36 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 062/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 17 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 063/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 064/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 065/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 066/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 3 J
#
#
# Epoch: 067/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 068/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 069/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
# Epoch: 070/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 071/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 072/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 11 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 073/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 074/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 075/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 15 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 076/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 077/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 12 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 3 J
#
#
# Epoch: 078/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 079/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 64 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 4 J
#
#
# Epoch: 080/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 081/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 082/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 083/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 30 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 084/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 085/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 3 J
#
#
# Epoch: 086/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 087/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 088/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 089/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 090/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 20 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 3 J
#
#
# Epoch: 091/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 092/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 093/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 094/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 095/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 096/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 097/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 2 J
#
#
# Epoch: 098/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
#
#
# Epoch: 099/100
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITHOUT AI: 0 J
#  - TOTAL ENERGY WASTED BY THE SYSTEM WITH AI: 0 J
